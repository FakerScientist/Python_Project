# %%
import pickle

with open('tier_1_2019_2022_RESHAPED.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#                                          TOURNAMENT        TEAM_0_NAME  \
# 0                          ESL One Birmingham  2019       TNC Predator
# 1                          ESL One Birmingham  2019       TNC Predator
# 2                          ESL One Birmingham  2019                 OG
# 3                          ESL One Birmingham  2019                 OG
# 4                          ESL One Birmingham  2019  Ninjas in Pyjamas
# ...                                             ...                ...
# 8855  DPC 2022 Winter Tour -  Western Europe Finals        Team Liquid
# 8856  DPC 2022 Winter Tour -  Western Europe Finals  Gaimin Gladiators
# 8857  DPC 2022 Winter Tour -  Western Europe Finals  Gaimin Gladiators
# 8858                         ESL One Stockholm 2022     Tundra Esports
# 8859                         ESL One Stockholm 2022                 OG
#
#                                           TEAM_0_HEROES TEAM_0_SIDE  \
# ...

# %%
import pickle

with open('ti_dpc_div2.pkl', 'rb') as g:
    data2 = pickle.load(g)
    
data2
# Out:
#                                            TOURNAMENT  \
# 0    DPC 2023 Winter Tour - Western Europe Division 1
# 1    DPC 2023 Winter Tour - Western Europe Division 1
# 2    DPC 2023 Winter Tour - Southeast Asia Division 1
# 3    DPC 2023 Winter Tour - Southeast Asia Division 1
# 4    DPC 2023 Winter Tour - Eastern Europe Division 1
# ..                                                ...
# 644  DPC 2022 Summer Tour - Southeast Asia Division 2
# 645  DPC 2022 Summer Tour - Southeast Asia Division 2
# 646  DPC 2022 Summer Tour - Western Europe Division 2
# 647  DPC 2022 Summer Tour - Western Europe Division 2
# 648  DPC 2022 Summer Tour - Western Europe Division 2
#
#                  TEAM_0_NAME  \
# 0                Team Secret
# 1                         OG
# 2    Blacklist International
# 3                   Team SMG
# 4                   One Move
# ..                       ...
# 644                 Atlantis
# 645                   Lilgun
# 646              DGG Esports
# ...

# %%
import  pandas as pd
import numpy as np

pd.DataFrame(data)
# Out:
#                                          TOURNAMENT        TEAM_0_NAME  \
# 0                          ESL One Birmingham  2019       TNC Predator
# 1                          ESL One Birmingham  2019       TNC Predator
# 2                          ESL One Birmingham  2019                 OG
# 3                          ESL One Birmingham  2019                 OG
# 4                          ESL One Birmingham  2019  Ninjas in Pyjamas
# ...                                             ...                ...
# 8855  DPC 2022 Winter Tour -  Western Europe Finals        Team Liquid
# 8856  DPC 2022 Winter Tour -  Western Europe Finals  Gaimin Gladiators
# 8857  DPC 2022 Winter Tour -  Western Europe Finals  Gaimin Gladiators
# 8858                         ESL One Stockholm 2022     Tundra Esports
# 8859                         ESL One Stockholm 2022                 OG
#
#                                           TEAM_0_HEROES TEAM_0_SIDE  \
# ...

# %%
data.to_csv('tier_1_2019_2022_reshaped.csv', encoding='utf-8', index=False)
